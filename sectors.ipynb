# %%
import json

# %%
sector_mapping = {
    # GPU / Semiconductors
    "NVIDIA": "GPU Providers",
    "AMD": "GPU Providers",
    "Intel": "GPU Providers",
    "TSMC": "GPU Providers",
    "ASML": "GPU Providers",
    "Qualcomm": "Semiconductors",
    "Broadcom": "Semiconductors",
    "Micron": "Semiconductors",
    "Samsung Electronics": "Semiconductors",
    "Texas Instruments": "Semiconductors",

    # Banking & Financial Services
    "JPMorgan": "Banking",
    "Goldman Sachs": "Banking",
    "Morgan Stanley": "Banking",
    "Citigroup": "Banking",
    "Bank of America": "Banking",
    "HSBC": "Banking",
    "Deutsche Bank": "Banking",
    "Barclays": "Banking",
    "UBS": "Banking",
    "Wells Fargo": "Banking",

    # Fintech / Neobank
    "Revolut": "Neobank",
    "Chime": "Neobank",
    "Nubank": "Neobank",
    "Wise": "Fintech",
    "PayPal": "Fintech",
    "Block": "Fintech",
    "Robinhood": "Fintech",
    "Adyen": "Fintech",
    "Stripe": "Fintech",
    "SoFi": "Fintech",

    # Agriculture & Food
    "John Deere": "Agriculture",
    "Cargill": "Agriculture",
    "Archer Daniels Midland": "Agriculture",
    "Bayer Crop Science": "Agriculture",
    "Syngenta": "Agriculture",
    "Bunge": "Agriculture",
    "Nutrien": "Agriculture",
    "Tyson Foods": "Food Production",
    "Nestlé": "Food Production",
    "Unilever": "Food Production",

    # Energy & Oil
    "ExxonMobil": "Energy",
    "Chevron": "Energy",
    "Shell": "Energy",
    "BP": "Energy",
    "TotalEnergies": "Energy",
    "Saudi Aramco": "Energy",
    "Schlumberger": "Energy Services",
    "Halliburton": "Energy Services",
    "Eni": "Energy",
    "Petrobras": "Energy",

    # Technology & Software
    "Apple": "Tech",
    "Microsoft": "Tech",
    "Alphabet": "Tech",
    "Meta": "Tech",
    "Amazon": "Tech",
    "Oracle": "Enterprise Software",
    "SAP": "Enterprise Software",
    "Salesforce": "Enterprise Software",
    "Adobe": "Enterprise Software",
    "ServiceNow": "Enterprise Software",

    # Automotive & EV
    "Tesla": "Automotive",
    "Toyota": "Automotive",
    "Volkswagen": "Automotive",
    "Ford": "Automotive",
    "General Motors": "Automotive",
    "BYD": "Electric Vehicles",
    "NIO": "Electric Vehicles",
    "Rivian": "Electric Vehicles",
    "Hyundai": "Automotive",
    "Stellantis": "Automotive",

    # Pharmaceuticals & Biotech
    "Pfizer": "Pharma",
    "Moderna": "Pharma",
    "Johnson & Johnson": "Pharma",
    "Roche": "Pharma",
    "Novartis": "Pharma",
    "AstraZeneca": "Pharma",
    "Merck": "Pharma",
    "GSK": "Pharma",
    "Bristol Myers Squibb": "Pharma",
    "Eli Lilly": "Pharma",

    # Retail & Consumer
    "Walmart": "Retail",
    "Costco": "Retail",
    "Target": "Retail",
    "Home Depot": "Retail",
    "LVMH": "Luxury Goods",
    "Nike": "Apparel",
    "Adidas": "Apparel",
    "Zara": "Apparel",
    "IKEA": "Retail",
    "Amazon": "E-commerce",

    # Telecommunications
    "AT&T": "Telecom",
    "Verizon": "Telecom",
    "T-Mobile": "Telecom",
    "Vodafone": "Telecom",
    "China Mobile": "Telecom",
    "NTT": "Telecom",
    "Orange": "Telecom",
    "Telefonica": "Telecom",
    "Deutsche Telekom": "Telecom",
    "SK Telecom": "Telecom",

    # Aerospace & Defense
    "Boeing": "Aerospace",
    "Airbus": "Aerospace",
    "Lockheed Martin": "Defense",
    "Raytheon": "Defense",
    "Northrop Grumman": "Defense",
    "General Dynamics": "Defense",
    "BAE Systems": "Defense",
    "Safran": "Aerospace",
    "Rolls-Royce": "Aerospace",
    "Thales": "Defense",
}

# Save to JSON file
with open("data/sectors.json", "w", encoding="utf-8") as f:
    json.dump(sector_mapping, f, ensure_ascii=False, indent=4)

# %%
# Open the file and load JSON content
with open("data/sectors.json", "r") as f:
    sectors = json.load(f)

print(sectors)
# Out:
# {'NVIDIA': 'GPU Providers', 'AMD': 'GPU Providers', 'Intel': 'GPU Providers', 'TSMC': 'GPU Providers', 'ASML': 'GPU Providers', 'Qualcomm': 'Semiconductors', 'Broadcom': 'Semiconductors', 'Micron': 'Semiconductors', 'Samsung Electronics': 'Semiconductors', 'Texas Instruments': 'Semiconductors', 'JPMorgan': 'Banking', 'Goldman Sachs': 'Banking', 'Morgan Stanley': 'Banking', 'Citigroup': 'Banking', 'Bank of America': 'Banking', 'HSBC': 'Banking', 'Deutsche Bank': 'Banking', 'Barclays': 'Banking', 'UBS': 'Banking', 'Wells Fargo': 'Banking', 'Revolut': 'Neobank', 'Chime': 'Neobank', 'Nubank': 'Neobank', 'Wise': 'Fintech', 'PayPal': 'Fintech', 'Block': 'Fintech', 'Robinhood': 'Fintech', 'Adyen': 'Fintech', 'Stripe': 'Fintech', 'SoFi': 'Fintech', 'John Deere': 'Agriculture', 'Cargill': 'Agriculture', 'Archer Daniels Midland': 'Agriculture', 'Bayer Crop Science': 'Agriculture', 'Syngenta': 'Agriculture', 'Bunge': 'Agriculture', 'Nutrien': 'Agriculture', 'Tyson Foods': 'Food Production', 'Ne
# ...

# %%
import numpy as np
np.unique(list(sectors.values()))
# Out:
# array(['Aerospace', 'Agriculture', 'Apparel', 'Automotive', 'Banking',
#        'Defense', 'E-commerce', 'Electric Vehicles', 'Energy',
#        'Energy Services', 'Enterprise Software', 'Fintech',
#        'Food Production', 'GPU Providers', 'Luxury Goods', 'Neobank',
#        'Pharma', 'Retail', 'Semiconductors', 'Tech', 'Telecom'],
#       dtype='<U19')
