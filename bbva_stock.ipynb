# %%
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime, timedelta

# %%
tickers = ['BBVA', 'NU', 'SAN']  # Choose any 3 tickers
end_date = datetime.today()
start_date = end_date - timedelta(days=30)

# %%
# === Download Data ===
data = yf.download(tickers, start=start_date, end=end_date)['Close']
# Out:
# /tmp/ipykernel_107147/1168532371.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, start=start_date, end=end_date)['Close']
# [*********************100%***********************]  3 of 3 completed

# %%
data
# Out:
# Ticker           BBVA     NU    SAN
# Date
# 2025-09-29  19.030001  15.95  10.29
# 2025-09-30  19.250000  16.01  10.48
# 2025-10-01  19.219999  15.19  10.42
# 2025-10-02  19.080000  15.22  10.16
# 2025-10-03  19.250000  15.31  10.29
# 2025-10-06  18.799999  15.38  10.11
# 2025-10-07  18.590000  15.13   9.97
# 2025-10-08  18.900000  15.46  10.11
# 2025-10-09  18.480000  15.37   9.94
# 2025-10-10  18.040001  14.92   9.75
# 2025-10-13  18.340000  15.08  10.04
# 2025-10-14  18.570000  14.91   9.93
# 2025-10-15  18.260000  15.18   9.87
# 2025-10-16  19.480000  14.73   9.90
# 2025-10-17  19.570000  15.00   9.77
# 2025-10-20  20.120001  15.41   9.87
# 2025-10-21  19.559999  15.24   9.65
# 2025-10-22  19.670000  15.16   9.77
# 2025-10-23  19.660000  15.90   9.70
# 2025-10-24  19.639999  15.84   9.67

# %%
plt.figure(figsize=(10, 6))
for ticker in tickers:
    plt.plot(data.index, data[ticker], label=ticker)

plt.title('Stock Prices - Last 30 Days')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
